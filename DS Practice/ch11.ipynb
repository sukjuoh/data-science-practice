# %%
import numpy as np
import pandas as pd
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau

# %%
df = pd.read_csv("C:/Users/user/Downloads/datascience/Python/bike.csv")
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.iloc[:,1:].corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
#
#             humidity  windspeed    casual  registered     count
# ...

# %%
df[["casual", "registered", "count"]].corr(method = "spearman")
# Out:
#               casual  registered     count
# casual      1.000000    0.775785  0.847378
# registered  0.775785    1.000000  0.988901
# count       0.847378    0.988901  1.000000

# %%
stat,p = pearsonr(df["casual"], df["registered"])
print(stat)
print(p)
# Out:
# 0.49724968508700795
# 0.0

# %%
#1
df[["temp","atemp", "humidity", "casual"]].corr().min().min()
# Out:
# -0.34818689928736407

# %%
#2
df_corr = df.groupby("season")[["casual","atemp"]].corr()
df_corr = df_corr.reset_index()
df_corr.loc[df_corr["atemp"]<1,:]
# Out:
#    season level_1  casual     atemp
# 0       1  casual     1.0  0.478312
# 2       2  casual     1.0  0.378122
# 4       3  casual     1.0  0.381423
# 6       4  casual     1.0  0.443751

# %%
#3
df["is_sunny"] = np.where(df["weather"] ==1, 1, 0)

# %%
df.groupby("is_sunny")[["casual", "temp"]].corr()
# Out:
#                    casual      temp
# is_sunny
# 0        casual  1.000000  0.446361
#          temp    0.446361  1.000000
# 1        casual  1.000000  0.471053
#          temp    0.471053  1.000000
